# %% [markdown]
# Exercici1

# %%
class Song():
    def __init__(self,titol,autor,durada):
        self.titol= titol
        self.autor= autor
        self.durada= durada
    def info (self):
        print(f"TÍTOL: {self.titol}, COMPOSITOR: {self.autor}, DURADA: {self.durada} segons")

# %%
canço = Song ("Sofia parodia clash royale", "El rich mc",  120)

# %%
canço.info()
# Out:
# TÍTOL: Sofia parodia clash royale, COMPOSITOR: El rich mc, DURADA: 120 segons

# %% [markdown]
# apartat b

# %%
class Playlist():
    def __init__(self,song_list):
        self.song_list= song_list

    def afegir_canço(self,song):
        return song 
    
    def durada_total(self,total):
        self.total= total
        return total
    
    def mostrar_playlist(self,song_list):
        self.song_list=song_list
        return song_list
    
    def canço_mes_llarga(self):
        max_song = self.song_list
        return max_song

# %% [markdown]
# apartat c

# %%
class Song():
    def __init__(self,titol,autor,durada):
        self.titol= titol
        self.autor= autor
        self.durada= durada
    def info (self):
        print(f"TÍTOL: {self.titol}, COMPOSITOR: {self.autor}, DURADA: {self.durada} segons")

# %%
canço = Song ("Sofia parodia clash royale", "El rich mc",  120)

# %%
canço.info()
# Out:
# TÍTOL: Sofia parodia clash royale, COMPOSITOR: El rich mc, DURADA: 120 segons

# %%
canço2 = Song ("Haram ball theme", "Prestianni",  87)

# %%
canço2.info()
# Out:
# TÍTOL: Haram ball theme, COMPOSITOR: Prestianni, DURADA: 87 segons

# %%
class playlist ():
    def __init__ (self, canço, canço2,canço3):
        self.canço=canço
        self.canço2=canço2
        self.canço3=canço3

# %%
print (playlist)
# Out:
# <class '__main__.playlist'>

# %% [markdown]
# Ex2

# %%
class Personatge():
    def __init__ (self, nom, vida, forca, nivell):
        self.nom=nom
        self.vida=vida
        self.forca=forca
        self.nivell=nivell

    def atacar (self, Personatge_2):
        self.Personatge_2=Personatge_2
        return Personatge_2
    
    def mostrar_personatge(self):
        print(f"NOM: {self.nom}, VIDA: {self.vida}, FORÇA: {self.forca}, NIVELL: {self.nivell}")
        
    def pujar_nivell(self):
        self.nivell +=1
        return self.nivell
